# %%
import pandas as pd 
house_price=pd.read_csv("z.Data/house_price_bd.csv")
house_price.sample(n=7)
# Out:
#                                                   Title  Bedrooms  Bathrooms  \
# 762   Feel Satisfied Living In This 1227 Sq Ft Flat ...       3.0        3.0
# 3681  Vacant For Sale In Matuail, A 1050 Sq. Ft. Wel...       3.0        2.0
# 401   A Fine Flat Is Now For Sale Which Is In Mirpur...       3.0        4.0
# 2328  This 1270 Sq Ft Amazing Apartment Is Ready For...       3.0        3.0
# 3296  In The Location Of Bproperty Village, Narayang...       NaN        NaN
# 1871  At Kazirhat, A 1100 Sq Ft Apartment Is Up For ...       2.0        2.0
# 1005  Best Location For Your Office, This 2600 Sq Ft...       NaN        NaN
#
#      Floor_no Occupancy_status  Floor_area              City Price_in_taka  \
# 762         4           vacant      1227.0             dhaka    ৳5,800,000
# 3681        8           vacant      1050.0  narayanganj-city    ৳6,000,000
# 401         5           vacant      1460.0             dhaka   ৳11,000,000
# ...

# %% [markdown]
#   ### Let replace the ৳(string) to Numarical value

# %%
house_price["Price_in_taka"]=house_price["Price_in_taka"].str.replace("৳", "").str.replace(",", "").astype(float)

# %% [markdown]
# ### Now make other numaric

# %%
x= house_price.drop( "Price_in_taka", axis=1)
y= house_price["Price_in_taka"]

# %% [markdown]
# ### OK see what model we can chose

# %%
house_price.isna().sum()
# Out:
# Title                  0
# Bedrooms            1001
# Bathrooms           1001
# Floor_no             684
# Occupancy_status      99
# Floor_area            99
# City                   0
# Price_in_taka          0
# Location               6
# dtype: int64

# %% [markdown]
# ### Hm we see . So many missing. Okay then fillup

# %%
import numpy as np

house_price.loc[house_price["Bedrooms"].isna(), "Bedrooms"] = np.random.randint(
    1, house_price["Bedrooms"].max() + 1, 
    size=house_price["Bedrooms"].isna().sum()
)  
house_price.loc[house_price["Bathrooms"].isna(), "Bathrooms"] = np.random.randint(
    1, house_price["Bathrooms"].max() + 1, 
    size=house_price["Bathrooms"].isna().sum()
)
house_price.loc[house_price["Floor_no"].isna(), "Floor_no"] = np.random.randint(
    1, house_price["Floor_no"].max() + 1, 
    size=house_price["Floor_no"].isna().sum()
)
house_price["Occupancy_status"].fillna("Occupied", inplace=True)
house_price["Floor_area"].fillna(house_price["Floor_area"].mean(), inpalce=True)

area=["Gandaria, Sutrapur", "Middle Badda, Badda", "Madhya Ajampur, Dakshin Khan", "Section 6, Mirpur"]

house_price.loc[house_price["Location"].isna(), "Location"]= np.random.choice(area,p=[0.3,0.2,0.1,0.4])
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# Cell In[30], line 12
#       3 house_price.loc[house_price["Bedrooms"].isna(), "Bedrooms"] = np.random.randint(
#       4     1, house_price["Bedrooms"].max() + 1,
#       5     size=house_price["Bedrooms"].isna().sum()
#       6 )
#       7 house_price.loc[house_price["Bathrooms"].isna(), "Bathrooms"] = np.random.randint(
#       8     1, house_price["Bathrooms"].max() + 1,
#       9     size=house_price["Bathrooms"].isna().sum()
#      10 )
#      11 house_price.loc[house_price["Floor_no"].isna(), "Floor_no"] = np.random.randint(
# ---> 12     1, house_price["Floor_no"].max() + 1,
#      13     size=house_price["Floor_no"].isna().sum()
#      14 )
#      15 house_price["Occupancy_status"].fillna("Occupied", inplace=True)
#      16 house_price["Floor_area"].fillna(house_price["Floor_area"].mean(), inpalce=True)
#
# ...

# %%
from sklearn.model_selection import train_test_split

# Convert things(String) into numarical manner T/F 
x=pd.get_dummies(x,drop_first=True)  
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import Ridge
model= Ridge() 
model.fit(x_train, y_train) 
model.score(x_test, y_test)
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# Cell In[32], line 3
#       1 from sklearn.linear_model import Ridge
#       2 model= Ridge()
# ----> 3 model.fit(x_train, y_train)
#       4 model.score(x_test, y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:1239, in Ridge.fit(self, X, y, sample_weight)
#    1237 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
#    1238 xp, _ = get_namespace(X, y, sample_weight)
# ...
